# %% [markdown]
# ## Problema - Organización y búsqueda de productos en una tienda
#
# **Instrucción:** completa esta plantilla con tu diseño y desarrollo. Evita incluir soluciones generadas automáticamente.

# %%
# @title Ingrese datos
Sebastian Castillo
Samuel Mendez
Leonardo Gonzalez

# %% [markdown]
# ## 1) Descripción del problema **[1 pts]**
#
# Una tienda maneja una lista con los códigos numéricos de sus productos. Como los productos se registran a medida que llegan, los códigos inicialmente se encuentran desordenados.
#
# El encargado necesita desarrollar un programa que permita:
#
# Registrar una cantidad n de productos.
# Ordenar sus códigos utilizando Merge Sort.
# Buscar un código específico utilizando Búsqueda Binaria.

# %% [markdown]
# ## 2) Requerimientos **[2 pts]**
#
# Lista requerimientos **funcionales** y **no funcionales**.
#
#   RQFO1 Leer cantidad de productos n.
#   RQFO2 Leer el codigo de cada producto.
#   RQFO3 Muestra el orden de los codigos originales.
#   RQFO4: Ordenar los codigos de los productos de forma ascendente .
#   RQFO5: Leer el codigo del producto a buscar.
#   RQFO6: Mostrar la pocision del pructo si esta en la lista.
#
#
#   RQNFO1 El sistema debe permitir ingresar una cantidad n de productos variables.
#   RQNFO2 El sistema no debe alterar los codigos de los productos .
#   RQNFO3 El sistema debe devolver una lista con los codigos de los productos ordenados.
#   RQNFO4 El sistema debe permitir ingresar un codigo de producto para buscar.
#   RQNFO5 El sistema debe devolver la pocision del codigo del producto, si no se encuentra en la lista devuelve un mensaje.

# %% [markdown]
# ## 3) Historias de usuario **[2 pts]**
# Escribe 3–5 historias de usuario con el formato visto en clase:
# Incluye criterios de aceptación.
#
# Como usuario se debe tener la posibilidad de ingresar una cantidad n de productos, en base a la cantidad registrada se debe ingresar el codigo de cada producto y poder visualizar el orden inicial de los códigos.
#
# Como usuario se quiere visualizar el orden de los códigos de forma ascendente en un arreglo, para facilitar la busqueda y visualizacion.
#
# Como usuario se debe tener la posibilidad de ingresar el código de un producto para realizar su búsqueda en el arreglo, además de visualizar su posición, si se encuentra en el arreglo, de lo contario se debe recibir un mensaje que informe que el producto no se encuentra en la lista.
#
# Criterios de aceptación
# Entrada de cantidad de productos: n debe ser un número entero positivo ingresado de forma numérica.
# Entrada de códigos: Cada código de producto debe ser ingresado de forma numérica y debe corresponder a un producto registrado.
# Visualización inicial: El sistema debe mostrar los n códigos en el mismo orden en que fueron ingresados.
# Ordenamiento: El sistema debe mostrar los n códigos organizados de forma ascendente.
# Entrada para búsqueda: El código a buscar debe ser ingresado de forma numérica.
# Resultado de búsqueda: Si el código existe, el sistema debe mostrar su posición dentro del arreglo.
# Código inexistente: Si el código no se encuentra, el sistema debe mostrar un mensaje indicando que el producto no está en la lista.

# %% [markdown]
# ## 4) Diagramas de flujo **[5 pts]**
# Incluye el diagrama que muestre el proceso general
#
# ![Diagrama de flujo](<data:image/png;base64,...>)

# %% [markdown]
# ## 5) Diagramas de secuencia **[5 pts]**
# Incluye el diagrama que muestre el proceso general
#
# Adjunta imagen y descríbelo claramente.
#
# ![Diagrama de secuencia - Merge Sort](<data:image/png;base64,...>)

# %% [markdown]
# ![Diagrama de secuencia - Ordenamiento y Búsqueda](<data:image/png;base64,...>)

# %% [markdown]
# ## 6) Diagramas de casos de uso **[5 pts]**
# Incluye el diagrama que muestre el proceso general
#
# ![Diagrama de casos de uso](<data:image/png;base64,...>)

# %% [markdown]
# ## 7) Análisis de complejidad **[15 pts]**
# Incluye:
# - Justificación
# - Función T[n]
# - Mejor y peor caso con gráfica
#
# Merge Sort: Aplica Divide y Vencerás. Divide la lista en mitades (log_2 n) y las fusiona linealmente (O(n)), garantizando un rendimiento estable.
# Búsqueda Binaria: Requiere la lista ordenada. Descarta el 50% de los datos en cada paso comparando con el centro, reduciendo drásticamente las operaciones.
#
# ![complejidad.jpg](attachment:complejidad.jpg)

# %% [markdown]
# ## 8) Código funcional **[15 pts]**
# Incluye tu implementación completa.
#
# No pegues código incompleto; debe ser ejecutable.

# %%
# Escribe tu código aquí.
def merge(tab, p, q, r):
    L = tab[p:q+1]
    R = tab[q+1:r+1]
    
    i = 0
    j = 0
    for k in range(p, r + 1):
        if i < len(L) and (j >= len(R) or L[i] <= R[j]):
            tab[k] = L[i]
            i = i + 1
        else:
            tab[k] = R[j]
            j = j + 1
 
 
def merge_sort(tab, p, r):
    if p < r:
        q = (p + r) // 2
 
        merge_sort(tab, p, q)
        merge_sort(tab, q + 1, r)
        merge(tab, p, q, r)

def binary_search_desc(tab, x):
    lo, hi = 0, len(tab) - 1
    while lo <= hi:
        mid = (lo + hi) // 2
        if tab[mid] == x:
            return mid
        elif tab[mid] < x:
            lo = mid + 1
        else:
            hi = mid - 1
    return None
 
 
def main():
    n = int(input("Cantidad de productos (Valor NUMERICO entero): "))
 
    if n < 0:
        print("Valor no Valido")
    else:
        print("Valor valido, Valor guardado")
    tab = []
    for i in range(n):
        cod = int(input("Valor producto: "))
        tab.append(cod)
    merge_sort(tab, 0, len(tab) - 1)
 
    print("Lista ordenada de menor a mayor:")
    print(tab)
    x = int(input("Ingrese el valor a buscar: "))
    res = binary_search_desc(tab, x)
    print(f"El codigo del producto se encuentra en la posicion {res} de la lista")
 
 
main()
