# %% [markdown]
# ## Problema - Organización y búsqueda de productos en una tienda
#
# **Instrucción:** completa esta plantilla con tu diseño y desarrollo. Evita incluir soluciones generadas automáticamente.

# %%
# @title Ingrese datos
nombre_estudiante = "" # @param {"type":"string"}
carnet = None # @param {"type":"integer"}

# %% [markdown]
# ## 1) Descripción del problema **[1 pts]**
#
# Una tienda desea desarrollar un pequeño sistema para controlar la atención de clientes, registrar las operaciones realizadas y administrar su catálogo de productos.
#
# Para resolver el problema se deberán utilizar tres estructuras de datos diferentes:
#
# Cola: para administrar los clientes que esperan ser atendidos.
# Pila: para guardar el historial de las últimas operaciones realizadas.
# Lista doblemente enlazada: para administrar y recorrer el catálogo de productos.

# %% [markdown]
# ## 2) Requerimientos **[2 pts]**
#
# **REQUERIMIENTOS FUNCIONALES**
# Cola
# El sistema debe permitir ingresar una cantidad n correspondeinte a la cantidad de clientes.
# El sistema debe guardar los nombres de los n clientes y mostrar la cola de clientes esperando generada.
# El sistema debe permitir ingresar el nombre de un cliente mas (Siempre mientras este dentro de la cantidad anteriormente ingresada).
# Pila
# El sistema debe guardar en una pila cada cliente previamente atendido y mostrarlo.
# El sistema debe permitir deshacer el ultimo cliente atendido.
# Productos
# El sistema debe permitir guardar el codigo, nombre y precio del producto.
# El sistema debe mostrar la lista de todos los productos.
# El sistema debe permitir realizar la busqueda de uno de los productos, en base a su codigo.
# El sistema debe permitir eliminar un producto selleccionado en base a su codigo.
# El sistema debe mostrar la lista resultante de los cambios realizados por el usuario.
#
# **REQUERIMIENTOS NO FUNCIONALES**
# Rendimiento — El sistema procesa una cantidad n de clientes sin perder significativamente velocidad.
# Escalabilidad— El sistema debe permitir el ingreso de nuevos clientes, siempre que se encuentre en el rango hasta n sin rediseño.
# Disponibilidad— El sistema debe mostrar los mensajes informativos acerca de la cola de clientes (Antes y despues de atenderlos).
# Usabilidad — El sistema debe mostrar los mensajes acerca de las cola restante e indicar claramente el ingreso de los clientes
#
# Productos
# Rendimiento — El sistema procesa una cantidad n de productos sin perder significativamente velocidad.
# Escalabilidad — El sistema debe permitir el ingreso de nuevos productos(Nombre, codigo y precio), siempre que se encuentre en el rango sin rediseño.
# Disponibilidad— El sistema debe mostrar los mensajes informativos acerca de la cola de productos (Antes de mostrar y/o eliminar).
# Usabilidad — El sistema debe mostrar los mensajes acerca de las cola restante e indicar claramente el ingreso de los productos y sus especificaciones.

# %% [markdown]
# ## 3) Historias de usuario **[2 pts]**
#
# **PUNTO 1**
#
# **Cola de clientes**
#
# **Registrar clientes inicialmente**
#
# Como usuario, quiero registrar una cantidad inicial de clientes, para establecer el orden en que seran atendidos.
#
# **Agregar un cliente**
#
# Como usuario, quiero agregar un nuevo cliente a la cola, para que pueda esperar su turno de atencian.
#
# **Atender un cliente**
#
# Como usuario, quiero atender al siguiente cliente de la cola, para respetar el orden de llegada.
#
# **Mostrar clientes en espera**
#
# Como usuario, quiero visualizar los clientes que siguen esperando, para conocer quienes estan pendientes de atencion.
#
# **PUNTO 2**
#
# **Pila de clientes atendidos**
#
# **Registrar cliente atendido**
#
# Como usuario, quiero guardar en el historial cada cliente que ha sido atendido, para mantener un registro de las atenciones realizadas.
#
# **Consultar ultima atencion**
#
# Como usuario, quiero consultar el ultimo cliente atendido, para conocer cual fue la atencion mas reciente.
#
# **Deshacer ultima atencion**
#
# Como usuario, quiero deshacer la ultima atencion realizada, para corregir una atencion registrada por error.
#
# **Regresar cliente a la cola**
#
# Como usuario, quiero que el cliente cuya atencion fue deshecha regrese al inicio de la cola, para que pueda ser atendido nuevamente.
#
# **PUNTO 3**
#
# **Catalogo de productos**
#
# **Agregar producto**
#
# Como usuario, quiero agregar un producto al final del catalogo, para registrar nuevos productos disponibles en la tienda.
#
# **Mostrar productos de inicio a fin**
#
# Como usuario, quiero visualizar los productos desde el primero hasta el ultimo, para consultar el catalogo en orden ascendente.
#
# **Mostrar productos de fin a inicio**
#
# Como usuario, quiero visualizar los productos desde el ultimo hasta el primero, para recorrer el catalogo en orden inverso.
#
# **Buscar producto**
#
# Como usuario, quiero buscar un producto utilizando su codigo, para consultar rapidamente la informacion del producto.
#
# **Eliminar producto**
#
# Como usuario, quiero eliminar un producto utilizando su codigo, para mantener actualizado el catalogo de la tienda.

# %% [markdown]
# ## 4) Diagramas de flujo **[5 pts]**
#
#
# ![fju.png](attachment:fju.png)

# %% [markdown]
# ## 5) Diagramas de secuencia **[5 pts]**
#
# ![sec.png](attachment:sec.png)

# %% [markdown]
# ## 6) Diagramas de casos de uso **[5 pts]**
#
#
# ![csd.png](attachment:csd.png)

# %% [markdown]
# ## 7) Análisis de complejidad **[5 pts]**
#
# El análisis de complejidad es así debido a que el tema es ecuaciones lineales. Al ser lineal su peor caso es una función lineal, mientras que su mejor caso es una función constante.
#
# ![comple.png](attachment:comple.png)

# %% [markdown]
# ## 8) Código funcional **[10 pts]**
# Incluye tu implementación completa.
#
# No pegues código incompleto; debe ser ejecutable.

# %%
def cantidad(mensaje):
    while True:
        try:
            numero = int(input(mensaje))
            return numero
        except ValueError:
            print("Valor no valido, intentelo de nuevo.")


def mostrar_clientes(clientes):
    if len(clientes) == 0:
        print("No hay clientes esperando.")
    else:
        print("Clientes esperando:", " -> ".join(clientes))


def agr_cliente(clientes):
    nuevo = input("Ingrese el nuevo cliente: ")
    clientes.append(nuevo)
    print("Cliente agregado.")
    mostrar_clientes(clientes)


def atend_cliente(clientes, atendidos):
    if len(clientes) == 0:
        print("No hay clientes esperando.")
    else:
        cliente = clientes.pop(0)      # dequeue
        atendidos.append(cliente)      # push

        print("Atendiendo a:", cliente)
        mostrar_clientes(clientes)


def mostrar_ultimo_atendido(atendidos):
    if len(atendidos) == 0:
        print("No hay clientes atendidos.")
    else:
        print("Ultimo cliente atendido:", atendidos[-1])   # peek


def eliminar_at(clientes, atendidos):
    if len(atendidos) == 0:
        print("No hay atenciones para deshacer.")
    else:
        ultimo = atendidos.pop()       # pop
        clientes.insert(0, ultimo)

        print("Se deshizo la atencion de:", ultimo)
        print("Pila de atendidos:", atendidos)
        mostrar_clientes(clientes)


def agregar_producto(productos):
    codigo = cantidad("Ingrese el codigo: ")

    for i in range(len(productos)):
        if productos[i][0] == codigo:
            print("Ya existe un producto con ese codigo.")
            return

    nombre = input("Ingrese el nombre: ")
    precio = cantidad("Ingrese el precio: ")

    producto = [codigo, nombre, precio]
    productos.append(producto)

    print("Producto agregado.")


def mostrar_productos_normal(productos):
    if len(productos) == 0:
        print("No hay productos.")
    else:
        print("Productos del primero al ultimo:")

        for i in range(len(productos)):
            print(productos[i][0], "-", productos[i][1], "- $", productos[i][2])


def mostrar_productos_reves(productos):
    if len(productos) == 0:
        print("No hay productos.")
    else:
        print("Productos del ultimo al primero:")

        for i in range(len(productos) - 1, -1, -1):
            print(productos[i][0], "-", productos[i][1], "- $", productos[i][2])


def buscar_producto(productos):
    codigo = cantidad("Ingrese el codigo que desea buscar: ")
    encontrado = False

    for i in range(len(productos)):
        if productos[i][0] == codigo:
            print("Producto encontrado:")
            print(productos[i][0], "-", productos[i][1], "- $", productos[i][2])
            encontrado = True
            break

    if encontrado == False:
        print("Producto no encontrado.")


def eliminar_producto(productos):
    codigo = cantidad("Ingrese el codigo que desea eliminar: ")
    encontrado = False

    for i in range(len(productos)):
        if productos[i][0] == codigo:
            productos.pop(i)
            encontrado = True
            print("Producto eliminado.")
            break

    if encontrado == False:
        print("Producto no encontrado.")


clientes = []
atendidos = []
productos = []

n = cantidad("Numero de clientes: ")

for i in range(n):
    c = input("Ingrese el nombre del cliente: ")
    clientes.append(c)


while True:
    print("\nMENU")
    print("1. Agregar cliente")
    print("2. Atender cliente")
    print("3. Mostrar clientes esperando")
    print("4. Mostrar ultimo cliente atendido")
    print("5. Deshacer ultima atencion")
    print("6. Agregar producto")
    print("7. Mostrar productos del primero al ultimo")
    print("8. Mostrar productos del ultimo al primero")
    print("9. Buscar producto")
    print("10. Eliminar producto")
    print("0. Salir")

    opcion = cantidad("Seleccione una opcion: ")

    if opcion == 1:
        agr_cliente(clientes)

    elif opcion == 2:
        atend_cliente(clientes, atendidos)

    elif opcion == 3:
        mostrar_clientes(clientes)

    elif opcion == 4:
        mostrar_ultimo_atendido(atendidos)

    elif opcion == 5:
        eliminar_at(clientes, atendidos)

    elif opcion == 6:
        agregar_producto(productos)

    elif opcion == 7:
        mostrar_productos_normal(productos)

    elif opcion == 8:
        mostrar_productos_reves(productos)

    elif opcion == 9:
        buscar_producto(productos)

    elif opcion == 10:
        eliminar_producto(productos)

    elif opcion == 0:
        print("Programa finalizado.")
        break

    else:
        print("Opcion no valida.")

# %% [markdown]
# ## 9) pruebas **[15 pts]**

# %%
def test(input, expected_output):
  # CALCULE LA SOLUCION (asignela a got_output)
  got_output =input
  assert got_output == expected_output, f"se obtuvo {got_output}, pero se esperaba {expected_output}"
  print(f"Paso caso de prueba {input} -> {expected_output}")

# %% [markdown]
# ## Pruebas de enunciado
#
# Los casos de prueba proporcionados por el enunciado verifican la cola de clientes, la pila de clientes atendidos y el catálogo de productos. La entrada usada fue registrar inicialmente 4 clientes: Ana, Carlos, Laura y Mateo, por lo que la salida esperada era la cola Ana -> Carlos -> Laura -> Mateo. Luego, al atender un cliente, se esperaba mostrar Atendiendo a: Ana y que la cola quedara Carlos -> Laura -> Mateo; si después ingresaba Sofía, la cola debía quedar Carlos -> Laura -> Mateo -> Sofía. La salida obtenida en el programa coincide con esa lógica, porque atiende al primer cliente ingresado y agrega los nuevos clientes al final.
#
#
# También se probaron las operaciones de pila y productos. Para la pila, al atender Ana, Carlos y Laura, la salida esperada era que el último cliente atendido fuera Laura; al deshacer la última atención, Laura debía salir de la pila y regresar al inicio de la cola. En productos, la entrada usada fue agregar 101 Arroz 4500, 102 Leche 3800, 103 Pan 2500 y 104 Café 12000; la salida esperada era poder mostrarlos en orden normal e inverso, buscar por código y eliminar el producto 103. La salida obtenida cumple con lo solicitado: muestra los productos, encuentra el código indicado y al eliminar Pan la lista queda conceptualmente como Arroz <-> Leche <-> Café.

# %%
input = "4\nAna\nCarlos\nLaura\nMateo\n3\n2\n4\n5\n1\nSofia\n3\n0\n"

output = "Clientes esperando: Ana -> Carlos -> Laura -> Mateo\nAtendiendo a: Ana\nClientes esperando: Carlos -> Laura -> Mateo\nUltimo cliente atendido:" \
" Ana\nSe deshizo la atencion de: Ana\nClientes esperando: Ana -> Carlos -> Laura -> Mateo\n" \
"Cliente agregado.\nClientes esperando: Ana -> Carlos -> Laura -> Mateo -> Sofia\nPrograma finalizado."

input = "0\n6\n101\nArroz\n4500\n6\n102\nLeche\n3800\n6\n103\nPan\n2500\n6\n104\nCafe\n12000\n7\n8\n9\n103\n10\n103\n7\n0\n"

output = "Producto agregado.\nProducto agregado.\nProducto agregado.\n" \
"Producto agregado.\nProductos del primero al ultimo:\n101 - Arroz - $ 4500\n102 - Leche - $ 3800\n103 - Pan - $ 2500\n104 - Cafe - $ 12000\nProductos del ultimo al primero:\n104 - Cafe - $ 12000\n103 - Pan - $ 2500\n102 - Leche - $ 3800\n101 - Arroz - $ 4500\nProducto encontrado:\n103 - Pan - $ 2500\nProducto eliminado.\nProductos del primero al ultimo:\n101 - Arroz - $ 4500\n102 - Leche - $ 3800\n104 - Cafe - $ 12000\nPrograma finalizado."

test(input, output)

# %% [markdown]
# ## Pruebas propias
# input()
# 5
# Paula
# Sebastian
# Andres
# Valentina
# Mateo
# 3
# 2
# 4
# 5
# 1
# Camila
# 3
# 0
#
# Producto agregado.
#
# Producto agregado.
#
# Producto agregado.
#
# Producto agregado.
# Productos del primero al ultimo:
# 201 - Galletas - $ 2500
# 202 - Jugo - $ 4000
# 203 - Chocolate - $ 3500
# 204 - Cereal - $ 12000
# Productos del ultimo al primero:
# 204 - Cereal - $ 12000
# 203 - Chocolate - $ 3500
# 202 - Jugo - $ 4000
# 201 - Galletas - $ 2500
# Producto encontrado:
# 203 - Chocolate - $ 3500
# Producto eliminado.
# Productos del primero al ultimo:
# 201 - Galletas - $ 2500
# 202 - Jugo - $ 4000
# 204 - Cereal - $ 12000
# Programa finalizado.

# %%
input, output = "123", "123"
test(input,output)

# %% [markdown]
# ## Pruebas de Desempeño
# Qué va aquí?
#
# Medición empírica del tiempo de ejecución.
#
# Gráfica de comportamiento.
#
# Relación entre la gráfica obtenida y el análisis de complejidad teórico.
#
# #### Código base para benchmarking

# %%
# Calcula el tiempo de ejecucion con base a diferentes tamaños de la entrada
# y nos da una lista de resultados, cada resultado contiene el tamaño de la entrada
# y el tiempo de ejecucion
# TENER EN CUENTA ESTAS ENTRADAS PUEDEN VARIAR SEGÚN EL PROBLEMA


def bench(n: int, step: int = 1) -> list[tuple[int, float]]:
    print("Generando datos ...", end='')
    from random import randint
    import time
    results: list[tuple[int, float]] = []


    # AJUSTAR LAS ENTRADAS SEGÚN EL PROBLEMA
    for size in range(1, n, step):
        input = size

        ti = time.perf_counter()
        output = input # Ajustar a su función
        tf = time.perf_counter()


        delta = (tf - ti) * 1000
        print(".", end="")
        results.append((size, delta))
    return results


# === CODIGO PARA DIBUJAR ===


def dibujar(x, y, dimensiones=(7, 5)):
    assert len(x) == len(y)
    import matplotlib.pyplot as plt
    plt.figure(figsize=dimensiones)
    plt.plot(x, y)
    plt.show()


# === LLAMADO ===
tiempos = bench(10, step=1)


x = [size for size, timing in tiempos]
y = [timing for size, timing in tiempos]


dibujar(x, y)
